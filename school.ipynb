# %%
import pandas as pd

# Define the structure of the survey based on the extracted questionnaire.
survey_data = {
    "Participant ID": ["P1", "P2", "P3", "P4"],
    "Purchased Insurance Last 12 Months": ["Yes", "No", "Yes", "Yes"],
    "Types of Insurance Used": [
        "Health Insurance, Car Insurance",
        None,
        "Life Insurance, Travel Insurance",
        "Health Insurance, Property Insurance, Pet Insurance"
    ],
    "Importance_Price": [8, 5, 7, 6],
    "Importance_Coverage": [9, 6, 8, 7],
    "Importance_Customer Service": [7, 8, 9, 6],
    "Importance_Company Reputation": [6, 5, 8, 9],
    "Importance_Policy Flexibility": [7, 5, 6, 7],
    "Importance_Renewal Discounts": [5, 6, 7, 8],
    "Importance_Clear Terms": [8, 7, 9, 8],
    "Importance_Optional Add-ons": [6, 5, 7, 4],
    "Knowledge of Carbon Credits": [4, 2, 5, 3],
    "Understanding Carbon Credit Systems": [3, 2, 4, 5],
    "Relatives Believe in Carbon Credits": [5, 3, 4, 2],
    "Friends Buy Carbon Credits": [4, 2, 3, 3],
    "I am Skeptical about Carbon Credits": [6, 7, 5, 6],
    "Money from Carbon Credits Reduces Footprint": [2, 3, 4, 2],
    "Would Buy Carbon Credits with Products": [5, 3, 6, 2],
    "Preference_Car Emissions Offset": [5, 6, 7, 3],
    "Preference_Household Emissions Offset": [6, 7, 5, 4],
    "Preference_Travel Emissions Offset": [4, 5, 6, 3],
    "Gamification_Badges": [5, 6, 7, 4],
    "Gamification_Levels": [4, 5, 6, 5],
    "Gamification_Leaderboards": [3, 2, 5, 4],
    "Gamification_Challenges": [5, 6, 7, 3],
    "Discuss Climate Change": [5, 4, 6, 3],
    "Willing to Adjust Habits": [7, 6, 8, 5],
    "Follow Sustainability Influencers": [5, 3, 6, 4],
    "Optimistic about Climate Future": [4, 3, 5, 6],
    "Age": [25, 32, 40, 28],
    "Gender": ["Male", "Female", "Male", "Female"],
    "Education Level": ["Bachelor’s degree", "Some college", "Master degree", "High school diploma"],
    "Employment Status": ["Employed full-time", "Student", "Self-employed", "Employed part-time"],
    "Income Level": ["Average", "Slightly lower than average", "Higher than average", "Lower than average"],
    "Location": ["Urban", "Suburban", "Urban", "Rural"],
    "Country": ["USA", "Canada", "UK", "Australia"],
    "Marital Status": ["Single", "Married", "Single", "Married"],
    "Household Members": [1, 3, 2, 4],
    "Children under 18": ["No", "Yes", "Yes", "No"]
}

# Create DataFrame from the survey data
survey_df = pd.DataFrame(survey_data)

# Save to Excel
survey_df
# Out:
#   Participant ID Purchased Insurance Last 12 Months  \
# 0             P1                                Yes
# 1             P2                                 No
# 2             P3                                Yes
# 3             P4                                Yes
#
#                              Types of Insurance Used  Importance_Price  \
# 0                    Health Insurance, Car Insurance                 8
# 1                                               None                 5
# 2                   Life Insurance, Travel Insurance                 7
# 3  Health Insurance, Property Insurance, Pet Insu...                 6
#
#    Importance_Coverage  Importance_Customer Service  \
# 0                    9                            7
# 1                    6                            8
# 2                    8                            9
# 3                    7                            6
#
#    Importance_Company Reputation  Importance_Policy Flexibility  \
# ...
